# %%
import pandas as pd
import xgboost
import shap
print("Everything works!")
df = pd.read_csv('../data/application_train.csv')
print(f"Dataset loaded: {df.shape[0]} rows, {df.shape[1]} columns")
# Out:
# Everything works!
# Dataset loaded: 307511 rows, 122 columns
